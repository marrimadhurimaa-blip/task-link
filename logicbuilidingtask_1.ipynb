# %%
# Data Science Internship – February 2026
# Logic Building Task – 1

# 1. User Login Check

# Problem: Check if the entered username and password are correct

print("\n--- Task 1: User Login Check ---")

correct_username = "admin"
correct_password = "1234"

username = input("Enter username: ")
password = input("Enter password: ")

if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")


# 2. Pass / Fail Analyzer

# Problem: Count how many students passed and failed

print("\n--- Task 2: Pass / Fail Analyzer ---")

marks = [45, 78, 90, 33, 60]

passed = 0
failed = 0

for mark in marks:
    if mark >= 50:
        passed += 1
    else:
        failed += 1

print("Marks:", marks)
print("Total students passed:", passed)
print("Total students failed:", failed)



# 3. Simple Data Cleaner

# Problem: Remove extra spaces and convert names to lowercase

print("\n--- Task 3: Simple Data Cleaner ---")

names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []

for name in names:
    name = name.strip()    # remove extra spaces
    name = name.lower()    # convert to lowercase
    cleaned_names.append(name)

print("Original names:", names)
print("Cleaned names:", cleaned_names)



# 4. Message Length Analyzer

# Problem: Print length of each message and flag long messages

print("\n--- Task 4: Message Length Analyzer ---")

messages = ["Hi", "Welcome to the platform", "OK"]

for message in messages:
    length = len(message)
    print(f"Message: '{message}' | Length: {length}")

    if length > 10:
        print("→ Flag: Message longer than 10 characters")



# 5. Error Message Detector

# Problem: Count how many times 'ERROR' appears in logs

print("\n--- Task 5: Error Message Detector ---")

logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

print("System Logs:", logs)
print("Total number of ERROR messages:", error_count)


print("\nAll 5 tasks completed successfully ✅")
# Out:
# --- Task 1: User Login Check ---
# Enter username: admin
# Enter password: 1234
# Login Successful
#
# --- Task 2: Pass / Fail Analyzer ---
# Marks: [45, 78, 90, 33, 60]
# Total students passed: 3
# Total students failed: 2
#
# --- Task 3: Simple Data Cleaner ---
# Original names: [' Alice ', 'bob', ' CHARLIE ']
# Cleaned names: ['alice', 'bob', 'charlie']
#
# --- Task 4: Message Length Analyzer ---
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23
# → Flag: Message longer than 10 characters
# Message: 'OK' | Length: 2
#
# --- Task 5: Error Message Detector ---
# System Logs: ['INFO', 'ERROR', 'WARNING', 'ERROR']
# Total number of ERROR messages: 2
#
# All 5 tasks completed successfully ✅
